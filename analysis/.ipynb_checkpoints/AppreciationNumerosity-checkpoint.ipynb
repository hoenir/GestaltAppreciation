# %% [markdown]
# # Analysis Gestalt appreciation & numerosity estimation experiment

# %%
from statsmodels.stats.power import tt_solve_power, FTestPower
import pandas as pd
from pandas import DataFrame
from psychopy import data, core, gui, misc
import numpy as np
import seaborn as sns
from fuzzywuzzy import fuzz
#from ggplot import *
from scipy import stats
import matplotlib as mpl
mpl.use('pdf')
import statsmodels.formula.api as smf
import statsmodels.api as sm

from matplotlib import rcParams
rcParams['font.family'] = 'ubuntu'
from pivottablejs import pivot_ui
# %pylab inline
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /usr/local/lib/python2.7/dist-packages/fuzzywuzzy/fuzz.py:33: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# Populating the interactive namespace from numpy and matplotlib
# /usr/lib/python2.7/dist-packages/matplotlib/__init__.py:1352: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
tt_solve_power(effect_size = 0.43, alpha = 0.05, nobs=None, power = 0.8)
# Out:
# 44.40824513171133

# %%
# get data file names
files = gui.fileOpenDlg("../data", allowed="csv files (*.csv)|*.csv")

dfs = []

for filename in files:
    
    print(filename)
    df = pd.read_table(filename, sep=",") #only Appreciation trials 85
   
    dfs.append(df)
    
    
df = pd.concat(dfs, ignore_index=True)
# Out:
# /home/sander/Dropbox/exp/GestaltAppreciation/data/19201_Gestalt_exp1_2016_Apr_21_1208.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/15928_Gestalt_exp1_2016_May_03_1106.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/17959_Gestalt_exp1_2016_May_02_1508.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/11755_Gestalt_exp1_2016_Apr_21_1606.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/21511_Gestalt_exp1_2016_May_03_1405.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/20803_Gestalt_exp1_2016_Apr_28_1404.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/23125_Gestalt_exp1_2016_May_04_1404.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/20404_Gestalt_exp1_2016_May_02_1605.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/22339_Gestalt_exp1_2016_Apr_15_0910.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/22567_Gestalt_exp1_2016_May_02_1406.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/22246_Gestalt_exp1_2016_Apr_21_0913.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/21700_Gestalt_exp1_2016_Apr_27_1506.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/23143_Gestalt_exp1_2016_May_03_1309.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/18445_Gestalt_exp1_2016_Apr_21_1005.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/13201_Gestalt_exp1_2016_Apr_18_1709.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/20467_Gestalt_exp1_2016_Apr_28_1503.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/18913_Gestalt_exp1_2016_Apr_18_1405.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/20650_Gestalt_exp1_2016_Apr_18_1604.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/20353_Gestalt_exp1_2016_Apr_27_1412.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/19873_Gestalt_exp1_2016_Apr_21_1103.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/23068_Gestalt_exp1_2016_Apr_25_1714.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/11707_Gestalt_exp1_2016_Apr_15_1205.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/18019_Gestalt_exp1_2016_Apr_25_1505.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/21064_Gestalt_exp1_2016_Apr_21_1508.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/21661_Gestalt_exp1_2016_Apr_15_1104.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/22681_Gestalt_exp1_2016_Apr_15_1316.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/22819_Gestalt_exp1_2016_Apr_18_1505.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/16891_Gestalt_exp1_2016_Apr_15_1507.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/21436_Gestalt_exp1_2016_Apr_25_1410.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/20755_Gestalt_exp1_2016_May_03_1507.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/16522_Gestalt_exp1_2016_Apr_15_1406.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/20395_Gestalt_exp1_2016_Apr_25_1609.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/20959_Gestalt_exp1_2016_Apr_28_1007.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/21625_Gestalt_exp1_2016_May_03_0911.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/23086_Gestalt_exp1_2016_Apr_28_1203.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/9010_Gestalt_exp1_2016_May_03_1203.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/21127_Gestalt_exp1_2016_Apr_28_0910.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/P4_Gestalt_exp1_2016_mrt_24_1605.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/P1_Gestalt_exp1_2016_mrt_24_1432.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/P3_Gestalt_exp1_2016_mrt_24_1533.csv
# /home/sander/Dropbox/exp/GestaltAppreciation/data/P2_Gestalt_exp1_2016_mrt_24_1503.csv

# %%
df.head()
# Out:
#               images condition imgB imgA  trials.thisRepN  trials.thisTrialN  \
# 0                NaN       NaN  NaN  NaN              NaN                NaN
# 1  images/INVk16.bmp  inverted  NaN  NaN                0                  0
# 2  images/INVk12.bmp  inverted  NaN  NaN                0                  1
# 3     images/k07.bmp   gestalt  NaN  NaN                0                  2
# 4  images/INVk06.bmp  inverted  NaN  NaN                0                  3
#
#    trials.thisN  trials.thisIndex  numLoop.thisRepN  numLoop.thisTrialN  \
# 0           NaN               NaN               NaN                 NaN
# 1             0                70               NaN                 NaN
# 2             1                67               NaN                 NaN
# 3             2                 6               NaN                 NaN
# 4             3                64               NaN                 NaN
#
#       ...       numResp.rt              date  frameRate       expName  \
# 0     ...              NaN  2016_May_04_1404  59.903139  Gestalt_exp1
# 1     ...              NaN  2016_May_04_1404  59.903139  Gestalt_exp1
# 2     ...              NaN  2016_May_04_1404  59.903139  Gestalt_exp1
# 3     ...              NaN  2016_May_04_1404  59.903139  Gestalt_exp1
# 4     ...              NaN  2016_May_04_1404  59.903139  Gestalt_exp1
#
#    session  participant Unnamed: 27  Geslacht Geboortejaar  Totaalscore
# 0        1        23125         NaN       NaN          NaN          NaN
# 1        1        23125         NaN       NaN          NaN          NaN
# 2        1        23125         NaN       NaN          NaN          NaN
# 3        1        23125         NaN       NaN          NaN          NaN
# 4        1        23125         NaN       NaN          NaN          NaN
#
# [5 rows x 31 columns]

# %%
dfApp = df[pd.notnull(df.images)]       
dfNum = df[pd.notnull(df.imgA)]

print 'total len:', len(dfApp)
print 'total len:', len(dfNum)

#df.to_csv('partialsetApril2016' + '.csv', sep='\t')


#add var for img
dfApp.loc[:,"img"]= dfApp.images.str.extract("(\d+)")
dfNum.loc[:,"img"]= dfNum.imgA.str.extract("(\d+)")
# Out:
# total len: 3403
# total len: 3116

# %%
dfApp.head()
# Out:
#    Unnamed: 26  Unnamed: 27  condition              date       expName  \
# 1          NaN          NaN  scrambled  2016_Apr_21_1208  Gestalt_exp1
# 2          NaN          NaN  scrambled  2016_Apr_21_1208  Gestalt_exp1
# 3          NaN          NaN   inverted  2016_Apr_21_1208  Gestalt_exp1
# 4          NaN          NaN    gestalt  2016_Apr_21_1208  Gestalt_exp1
# 5          NaN          NaN  scrambled  2016_Apr_21_1208  Gestalt_exp1
#
#    frameRate             images imgA imgB key_resp_2.keys ...  \
# 1  60.250783     images/i02.bmp  NaN  NaN             NaN ...
# 2  60.250783     images/i23.bmp  NaN  NaN             NaN ...
# 3  60.250783  images/INVk10.bmp  NaN  NaN             NaN ...
# 4  60.250783     images/k08.bmp  NaN  NaN             NaN ...
# 5  60.250783     images/i21.bmp  NaN  NaN             NaN ...
#
#    rating.response  rating.rt  response.keys  response.rt  session  \
# 1                1      8.919            NaN          NaN        1
# 2                1      3.534            NaN          NaN        1
# 3                1      3.719            NaN          NaN        1
# 4                2      4.403            NaN          NaN        1
# 5                3      2.069            NaN          NaN        1
#
#   trials.thisIndex  trials.thisN trials.thisRepN  trials.thisTrialN img
# 1               31             0               0                  0  02
# 2               52             1               0                  1  23
# 3               66             2               0                  2  10
# 4                7             3               0                  3  08
# 5               50             4               0                  4  21
#
# [5 rows x 30 columns]

# %% [markdown]
# # Appreciation data
#
# * condition
# * rating.response
# * rating.rt

# %%
dfApp = dfApp.rename(columns={'rating.response': 'rating'})
print dfApp.columns
# Out:
# Index([u'Unnamed: 26', u'Unnamed: 27', u'condition', u'date', u'expName',
#        u'frameRate', u'images', u'imgA', u'imgB', u'key_resp_2.keys',
#        u'key_resp_2.rt', u'numLoop.thisIndex', u'numLoop.thisN',
#        u'numLoop.thisRepN', u'numLoop.thisTrialN', u'numResp.Alocation',
#        u'numResp.corr', u'numResp.keys', u'numResp.rt', u'participant',
#        u'rating', u'rating.rt', u'response.keys', u'response.rt', u'session',
#        u'trials.thisIndex', u'trials.thisN', u'trials.thisRepN',
#        u'trials.thisTrialN', u'img'],
#       dtype='object')

# %% [markdown]
# ### Does gestaltness influence appreciation?

# %%
#sns.violinplot(x="condition", y="rating.response", data=dfApp);
sns.pointplot(x="condition", y="rating",unit="participant", data=dfApp);

# %%
# GLM test

model = smf.glm(formula="rating ~ condition", data=dfApp)
#model = smf.ols(formula="rating ~ condition", data=dfApp)

results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 rating   No. Observations:                 3403
# Model:                            GLM   Df Residuals:                     3371
# Model Family:                Gaussian   Df Model:                           31
# Link Function:               identity   Scale:                   2.77727062245
# Method:                          IRLS   Log-Likelihood:                -6550.6
# Date:                 do, 26 mei 2016   Deviance:                       9362.2
# Time:                        02:09:12   Pearson chi2:                 9.36e+03
# No. Iterations:                     4
# ==========================================================================================
#                              coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ------------------------------------------------------------------------------------------
# Intercept                  4.8142      0.156     30.947      0.000         4.509     5.119
# condition[T.inverted]     -0.0419      0.074     -0.562      0.574        -0.188     0.104
# condition[T.scrambled]    -0.0837      0.067     -1.246      0.213        -0.215     0.048
# img[T.02]                 -0.3455      0.239     -1.448      0.148        -0.813     0.122
# img[T.03]                 -0.2276      0.213     -1.071      0.284        -0.644     0.189
# img[T.04]                  0.1382      0.213      0.650      0.515        -0.278     0.555
# img[T.05]                 -0.1138      0.213     -0.536      0.592        -0.530     0.303
# img[T.06]                  0.2683      0.213      1.263      0.207        -0.148     0.685
# img[T.07]                 -0.0163      0.239     -0.068      0.946        -0.484     0.451
# img[T.08]                  0.3008      0.239      1.261      0.207        -0.167     0.768
# img[T.09]                  0.1301      0.213      0.612      0.540        -0.286     0.547
# img[T.10]                 -0.3089      0.213     -1.454      0.146        -0.725     0.108
# img[T.11]                 -0.3211      0.239     -1.346      0.178        -0.789     0.147
# img[T.12]                  0.1951      0.213      0.918      0.359        -0.221     0.612
# img[T.13]                  0.6423      0.239      2.692      0.007         0.175     1.110
# img[T.14]                  0.4228      0.213      1.989      0.047         0.006     0.839
# img[T.15]                 -0.1138      0.213     -0.536      0.592        -0.530     0.303
# img[T.16]                 -0.3659      0.213     -1.722      0.085        -0.782     0.051
# img[T.17]                 -0.6504      0.239     -2.726      0.006        -1.118    -0.183
# img[T.18]                  0.1301      0.213      0.612      0.540        -0.286     0.547
# img[T.19]                 -0.3008      0.213     -1.416      0.157        -0.717     0.116
# img[T.20]                 -0.3211      0.239     -1.346      0.178        -0.789     0.147
# img[T.21]                  0.0163      0.213      0.077      0.939        -0.400     0.433
# img[T.22]                 -0.0325      0.213     -0.153      0.878        -0.449     0.384
# img[T.23]                  0.0163      0.213      0.077      0.939        -0.400     0.433
# img[T.24]                 -0.5772      0.213     -2.716      0.007        -0.994    -0.161
# img[T.25]                 -0.1870      0.213     -0.880      0.379        -0.603     0.230
# img[T.26]                  0.3252      0.213      1.530      0.126        -0.091     0.742
# img[T.27]                  0.1220      0.213      0.574      0.566        -0.295     0.538
# img[T.28]                  0.0325      0.213      0.153      0.878        -0.384     0.449
# img[T.29]                 -0.3496      0.213     -1.645      0.100        -0.766     0.067
# img[T.30]                  0.1870      0.213      0.880      0.379        -0.230     0.603
# ==========================================================================================

# %% [markdown]
# ## Correlation between individual difference scores (appreciation of Gestalt minus scrambled patterns) and PNS scores

# %%
# compute diff score to correlate with PNS score

print(len(dfApp['participant'].unique()))

def diffScore(df):
    
    gestaltm =  df[df.condition=='gestalt'].rating.mean()
    scrambledm = df[df.condition=='scrambled'].rating.mean()
    
    diff= gestaltm - scrambledm
    
    #df['id'].iloc[0]
    dfout = pd.DataFrame(data=[(gestaltm, scrambledm, diff)], columns=['gestaltm', 'scrambledm', 'diff'])
    
    return dfout

dfdiff = dfApp.groupby('participant').apply(diffScore)
dfdiff = dfdiff.reset_index()


# add PNS scores
dfPNS = pd.read_table("ScoringPNS.csv", sep=",") 
dfPNS = dfPNS.iloc[4:,:]
dfPNS["participant"] = pd.to_numeric(dfPNS["participant"])
dfmerged= pd.merge(dfdiff, dfPNS, how='outer', on='participant')
dfmerged.head()
# Out:
# 41
#   participant  level_1  gestaltm  scrambledm      diff Geslacht  Geboortejaar  \
# 0        9010        0  5.000000    4.966667  0.033333    vrouw          1992
# 1       11707        0  5.300000    4.966667  0.333333    vrouw          1995
# 2       11755        0  5.466667    5.866667 -0.400000    vrouw          1995
# 3       13201        0  4.933333    4.500000  0.433333    vrouw          1994
# 4       15928        0  5.066667    4.966667  0.100000    vrouw          1996
#
#    Totaalscore
# 0           59
# 1           49
# 2           46
# 3           34
# 4           42

# %% [markdown]
# ### Does higher PNS (personal need for structure) imply higher relative appreciation of Gestalt vs scrambled patterns?

# %%
sns.jointplot(x="Totaalscore", y="diff", data=dfmerged, kind="reg");
dfmerged["diff"].mean()
# Out:
# 0.083739837398373998

# %% [markdown]
# # Numerosity data

# %%
#print dfNum.columns
#print dfNum.dtypes
dfNum = dfNum.rename(columns={'numResp.corr': 'acc','numResp.rt': 'rt', 'numResp.Alocation': 'Alocation' })
dfNum.head()
# Out:
#     Unnamed: 26  Unnamed: 27           condition              date  \
# 85          NaN          NaN   Gestalt-scrambled  2016_Apr_21_1208
# 86          NaN          NaN    Inverted-Gestalt  2016_Apr_21_1208
# 87          NaN          NaN   Gestalt-scrambled  2016_Apr_21_1208
# 88          NaN          NaN   Gestalt-scrambled  2016_Apr_21_1208
# 89          NaN          NaN  Inverted-scrambled  2016_Apr_21_1208
#
#          expName  frameRate images               imgA            imgB  \
# 85  Gestalt_exp1  60.250783    NaN     images/k18.bmp  images/i18.bmp
# 86  Gestalt_exp1  60.250783    NaN  images/INVk03.bmp  images/k02.bmp
# 87  Gestalt_exp1  60.250783    NaN     images/k05.bmp  images/i05.bmp
# 88  Gestalt_exp1  60.250783    NaN     images/k22.bmp  images/i22.bmp
# 89  Gestalt_exp1  60.250783    NaN  images/INVk03.bmp  images/i02.bmp
#
#    key_resp_2.keys ...  rating.response  rating.rt  response.keys  \
# 85             NaN ...              NaN        NaN            NaN
# 86             NaN ...              NaN        NaN            NaN
# 87             NaN ...              NaN        NaN            NaN
# 88             NaN ...              NaN        NaN            NaN
# 89             NaN ...              NaN        NaN            NaN
#
#     response.rt  session trials.thisIndex  trials.thisN trials.thisRepN  \
# 85          NaN        1              NaN           NaN             NaN
# 86          NaN        1              NaN           NaN             NaN
# 87          NaN        1              NaN           NaN             NaN
# 88          NaN        1              NaN           NaN             NaN
# 89          NaN        1              NaN           NaN             NaN
#
#     trials.thisTrialN img
# 85                NaN  18
# 86                NaN  03
# 87                NaN  05
# 88                NaN  22
# 89                NaN  03
#
# [5 rows x 30 columns]

# %%
dfNum.columns
#dfNum["condition"].loc[dfNum.condition== "Inverted-scrambled"]= "Scrambled-Inverted"

# %%
dfNum.head()
# Out:
#     Unnamed: 26  Unnamed: 27           condition              date  \
# 85          NaN          NaN   Gestalt-scrambled  2016_Apr_21_1208
# 86          NaN          NaN    Inverted-Gestalt  2016_Apr_21_1208
# 87          NaN          NaN   Gestalt-scrambled  2016_Apr_21_1208
# 88          NaN          NaN   Gestalt-scrambled  2016_Apr_21_1208
# 89          NaN          NaN  Inverted-scrambled  2016_Apr_21_1208
#
#          expName  frameRate images               imgA            imgB  \
# 85  Gestalt_exp1  60.250783    NaN     images/k18.bmp  images/i18.bmp
# 86  Gestalt_exp1  60.250783    NaN  images/INVk03.bmp  images/k02.bmp
# 87  Gestalt_exp1  60.250783    NaN     images/k05.bmp  images/i05.bmp
# 88  Gestalt_exp1  60.250783    NaN     images/k22.bmp  images/i22.bmp
# 89  Gestalt_exp1  60.250783    NaN  images/INVk03.bmp  images/i02.bmp
#
#    key_resp_2.keys        ...         participant  rating.response  rating.rt  \
# 85             NaN        ...               19201              NaN        NaN
# 86             NaN        ...               19201              NaN        NaN
# 87             NaN        ...               19201              NaN        NaN
# 88             NaN        ...               19201              NaN        NaN
# 89             NaN        ...               19201              NaN        NaN
#
#     response.keys  response.rt session  trials.thisIndex trials.thisN  \
# 85            NaN          NaN       1               NaN          NaN
# 86            NaN          NaN       1               NaN          NaN
# 87            NaN          NaN       1               NaN          NaN
# 88            NaN          NaN       1               NaN          NaN
# 89            NaN          NaN       1               NaN          NaN
#
#     trials.thisRepN trials.thisTrialN
# 85              NaN               NaN
# 86              NaN               NaN
# 87              NaN               NaN
# 88              NaN               NaN
# 89              NaN               NaN
#
# [5 rows x 29 columns]

# %%
sns.pointplot(x="condition", y="acc",unit="participant", data=dfNum);

# %%
model = smf.glm(formula="acc ~ condition", data=dfNum,  family=sm.families.Binomial())

results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                    acc   No. Observations:                 3116
# Model:                            GLM   Df Residuals:                     3113
# Model Family:                Binomial   Df Model:                            2
# Link Function:                  logit   Scale:                             1.0
# Method:                          IRLS   Log-Likelihood:                -2142.8
# Date:                 do, 26 mei 2016   Deviance:                       4285.5
# Time:                        01:47:51   Pearson chi2:                 3.12e+03
# No. Iterations:                     6
# ===================================================================================================
#                                       coef    std err          z      P>|z|      [95.0% Conf. Int.]
# ---------------------------------------------------------------------------------------------------
# Intercept                          -0.2848      0.058     -4.945      0.000        -0.398    -0.172
# condition[T.Inverted-Gestalt]       0.1893      0.087      2.176      0.030         0.019     0.360
# condition[T.Inverted-scrambled]     0.1083      0.087      1.243      0.214        -0.062     0.279
# ===================================================================================================

# %% [markdown]
# # Checking for low-level characteristics

# %%
# prerequisites

import os, re
import matplotlib.pyplot as plt
from skimage.data import data_dir
from skimage.util import img_as_ubyte
from skimage.morphology import skeletonize, convex_hull_image
from skimage import io
from skimage.measure import label, regionprops


def plot_comparison(original, filtered, filter_name):

    fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(8, 4), sharex=True,
                                   sharey=True)
    ax1.imshow(original, cmap=plt.cm.gray)
    ax1.set_title('original')
    ax1.axis('off')
    ax1.set_adjustable('box-forced')
    ax2.imshow(filtered, cmap=plt.cm.gray)
    ax2.set_title(filter_name)
    ax2.axis('off')
    ax2.set_adjustable('box-forced')

# %%
# get data file names
files = gui.fileOpenDlg("../images", allowed="bmp files (*.bmp)|*.bmp")

d = []

for filename in files:
    
    #print(filename)
    stim = io.imread(filename, as_grey=True)
    stim = img_as_ubyte(io.imread(filename, as_grey=True))
    #fig, ax = plt.subplots()
    #ax.imshow(stim, cmap=plt.cm.gray)
    chull = convex_hull_image(stim == 0)
    #plot_comparison(stim, chull, 'convex hull')
    label_img = label(chull)
    regions_img = regionprops(label_img)
    region = regions_img[0]

    hull= float(region.convex_area)/(chull.shape[0]*chull.shape[1])
    print "percentage pixels of convex hull image: ", hull
    d.append({'images': filename.split("GestaltAppreciation/")[1] ,'hull': hull})

#print d                 
stims = pd.DataFrame(d)
# Out:
# percentage pixels of convex hull image:  0.433644444444
# percentage pixels of convex hull image:  0.614855555556
# percentage pixels of convex hull image:  0.526588888889
# percentage pixels of convex hull image:  0.291833333333
# percentage pixels of convex hull image:  0.390255555556
# percentage pixels of convex hull image:  0.463811111111
# percentage pixels of convex hull image:  0.557422222222
# percentage pixels of convex hull image:  0.447044444444
# percentage pixels of convex hull image:  0.732866666667
# percentage pixels of convex hull image:  0.235755555556
# percentage pixels of convex hull image:  0.613522222222
# percentage pixels of convex hull image:  0.273833333333
# percentage pixels of convex hull image:  0.204877777778
# percentage pixels of convex hull image:  0.602644444444
# percentage pixels of convex hull image:  0.496922222222
# percentage pixels of convex hull image:  0.478988888889
# percentage pixels of convex hull image:  0.355022222222
# percentage pixels of convex hull image:  0.150611111111
# percentage pixels of convex hull image:  0.655833333333
# percentage pixels of convex hull image:  0.4285
# percentage pixels of convex hull image:  0.288477777778
# percentage pixels of convex hull image:  0.422244444444
# percentage pixels of convex hull image:  0.375311111111
# percentage pixels of convex hull image:  0.628844444444
# percentage pixels of convex hull image:  0.564177777778
# percentage pixels of convex hull image:  0.405377777778
# percentage pixels of convex hull image:  0.319866666667
# percentage pixels of convex hull image:  0.177255555556
# percentage pixels of convex hull image:  0.265788888889
# percentage pixels of convex hull image:  0.284455555556
# percentage pixels of convex hull image:  0.465277777778
# percentage pixels of convex hull image:  0.607122222222
# percentage pixels of convex hull image:  0.613244444444
# percentage pixels of convex hull image:  0.572244444444
# percentage pixels of convex hull image:  0.452622222222
# percentage pixels of convex hull image:  0.487544444444
# percentage pixels of convex hull image:  0.578677777778
# percentage pixels of convex hull image:  0.551266666667
# percentage pixels of convex hull image:  0.697811111111
# percentage pixels of convex hull image:  0.684633333333
# percentage pixels of convex hull image:  0.185266666667
# percentage pixels of convex hull image:  0.399566666667
# percentage pixels of convex hull image:  0.272788888889
# percentage pixels of convex hull image:  0.292633333333
# percentage pixels of convex hull image:  0.633611111111
# percentage pixels of convex hull image:  0.2814
# percentage pixels of convex hull image:  0.477833333333
# percentage pixels of convex hull image:  0.529333333333
# percentage pixels of convex hull image:  0.478244444444
# percentage pixels of convex hull image:  0.638977777778
# percentage pixels of convex hull image:  0.322911111111
# percentage pixels of convex hull image:  0.399055555556
# percentage pixels of convex hull image:  0.611244444444
# percentage pixels of convex hull image:  0.442266666667
# percentage pixels of convex hull image:  0.697722222222
# percentage pixels of convex hull image:  0.291833333333
# percentage pixels of convex hull image:  0.639822222222
# percentage pixels of convex hull image:  0.556033333333
# percentage pixels of convex hull image:  0.555222222222
# percentage pixels of convex hull image:  0.256966666667
# percentage pixels of convex hull image:  0.405377777778
# percentage pixels of convex hull image:  0.428633333333
# percentage pixels of convex hull image:  0.375122222222
# percentage pixels of convex hull image:  0.284544444444
# percentage pixels of convex hull image:  0.150577777778
# percentage pixels of convex hull image:  0.496866666667
# percentage pixels of convex hull image:  0.177222222222
# percentage pixels of convex hull image:  0.422333333333
# percentage pixels of convex hull image:  0.320022222222
# percentage pixels of convex hull image:  0.478777777778
# percentage pixels of convex hull image:  0.603511111111
# percentage pixels of convex hull image:  0.732966666667
# percentage pixels of convex hull image:  0.204844444444
# percentage pixels of convex hull image:  0.613488888889
# percentage pixels of convex hull image:  0.446866666667
# percentage pixels of convex hull image:  0.390111111111
# percentage pixels of convex hull image:  0.273577777778
# percentage pixels of convex hull image:  0.557166666667
# percentage pixels of convex hull image:  0.463766666667
# percentage pixels of convex hull image:  0.526711111111
# percentage pixels of convex hull image:  0.614766666667
# percentage pixels of convex hull image:  0.433477777778
# percentage pixels of convex hull image:  0.257222222222

# %%
dfmerged= pd.merge(dfApp, stims, how='outer', on='images')
dfmerged.head()
# Out:
#    Unnamed: 26  Unnamed: 27  condition              date       expName  \
# 0          NaN          NaN  scrambled  2016_Apr_21_1208  Gestalt_exp1
# 1          NaN          NaN  scrambled  2016_May_03_1106  Gestalt_exp1
# 2          NaN          NaN  scrambled  2016_May_02_1508  Gestalt_exp1
# 3          NaN          NaN  scrambled  2016_Apr_21_1606  Gestalt_exp1
# 4          NaN          NaN  scrambled  2016_May_03_1405  Gestalt_exp1
#
#    frameRate          images imgA imgB key_resp_2.keys    ...     rating.rt  \
# 0  60.250783  images/i02.bmp  NaN  NaN             NaN    ...         8.919
# 1  59.918629  images/i02.bmp  NaN  NaN             NaN    ...         1.536
# 2  59.690780  images/i02.bmp  NaN  NaN             NaN    ...         1.068
# 3  59.929758  images/i02.bmp  NaN  NaN             NaN    ...         1.869
# 4  59.927275  images/i02.bmp  NaN  NaN             NaN    ...         1.352
#
#    response.keys  response.rt  session  trials.thisIndex trials.thisN  \
# 0            NaN          NaN        1                31            0
# 1            NaN          NaN        1                31           22
# 2            NaN          NaN        1                31           73
# 3            NaN          NaN        1                31           45
# 4            NaN          NaN        1                31           47
#
#    trials.thisRepN trials.thisTrialN  img      hull
# 0                0                 0   02  0.556033
# 1                0                22   02  0.556033
# 2                0                73   02  0.556033
# 3                0                45   02  0.556033
# 4                0                47   02  0.556033
#
# [5 rows x 31 columns]

# %%
sns.lmplot(x="rating", y="hull", data=dfmerged, x_estimator=np.mean);

# %%
#sns.violinplot(x="condition", y="rating.response", data=dfApp);
sns.pointplot(x="condition", y="hull", data=dfmerged);

# %%
# GLM test

model = smf.glm(formula="rating ~ condition * hull", data=dfmerged)
#model = smf.ols(formula="rating ~ hull", data=dfmerged)

results = model.fit()
print(results.summary())
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:                 rating   No. Observations:                 3403
# Model:                            GLM   Df Residuals:                     3397
# Model Family:                Gaussian   Df Model:                            5
# Link Function:               identity   Scale:                   2.82427229135
# Method:                          IRLS   Log-Likelihood:                -6592.2
# Date:                 do, 26 mei 2016   Deviance:                       9594.1
# Time:                        03:21:32   Pearson chi2:                 9.59e+03
# No. Iterations:                     4
# ===============================================================================================
#                                   coef    std err          z      P>|z|      [95.0% Conf. Int.]
# -----------------------------------------------------------------------------------------------
# Intercept                       5.1433      0.138     37.255      0.000         4.873     5.414
# condition[T.inverted]          -0.0990      0.215     -0.461      0.645        -0.519     0.322
# condition[T.scrambled]         -0.6150      0.226     -2.717      0.007        -1.059    -0.171
# hull                           -0.9028      0.314     -2.877      0.004        -1.518    -0.288
# condition[T.inverted]:hull      0.1937      0.484      0.400      0.689        -0.755     1.143
# condition[T.scrambled]:hull     1.2206      0.467      2.613      0.009         0.305     2.136
# ===============================================================================================
